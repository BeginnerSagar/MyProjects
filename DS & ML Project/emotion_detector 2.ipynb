# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Function to load data
def load_data(data_dir, emotion_labels):
    faces = []
    emotions = []
    for label in emotion_labels:
        emotion_dir = os.path.join(data_dir, label)
        for img_name in os.listdir(emotion_dir):
            img_path = os.path.join(emotion_dir, img_name)
            img = tf.keras.preprocessing.image.load_img(img_path, color_mode='grayscale', target_size=(48, 48))
            img = tf.keras.preprocessing.image.img_to_array(img)
            img = img / 255.0
            faces.append(img)
            emotions.append(emotion_labels.index(label))
    return np.array(faces), np.array(emotions)

# Define base path
base_dir = r"C:\Users\sagar\OneDrive\Desktop\DS & ML Project\fer2013_dataset"

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Define train and test paths
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Load training and testing data
train_faces, train_emotions = load_data(train_dir, emotion_labels)
test_faces, test_emotions = load_data(test_dir, emotion_labels)

# One-hot encode the emotion labels
train_emotions = to_categorical(train_emotions, num_classes=len(emotion_labels))
test_emotions = to_categorical(test_emotions, num_classes=len(emotion_labels))

# Split training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_faces, train_emotions, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization, Input

# %%
# Build the model
model = Sequential()

# Input layer
model.add(Input(shape=(48, 48, 1)))

# 1st CNN layer
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 2nd CNN layer
model.add(Conv2D(128, (5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 3rd CNN layer
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 4th CNN layer
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Output layer
model.add(Dense(7, activation='softmax'))

# %%
# Build the model
model = Sequential()

# Input layer
model.add(Input(shape=(48, 48, 1)))

# 1st CNN layer
model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 2nd CNN layer
model.add(Conv2D(128, (5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 3rd CNN layer
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 4th CNN layer
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Output layer
model.add(Dense(7, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 293s 397ms/step - accuracy: 0.2410 - loss: 2.1149 - val_accuracy: 0.3441 - val_loss: 1.6977
# Epoch 2/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.4187 - loss: 1.5167 - val_accuracy: 0.3295 - val_loss: 1.6940
# Epoch 3/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 392ms/step - accuracy: 0.5112 - loss: 1.2867 - val_accuracy: 0.4920 - val_loss: 1.3232
# Epoch 4/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.5583 - loss: 1.1686 - val_accuracy: 0.5430 - val_loss: 1.1986
# Epoch 5/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 392ms/step - accuracy: 0.5950 - loss: 1.0885 - val_accuracy: 0.5343 - val_loss: 1.2065
# Epoch 6/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 392ms/step - accuracy: 0.6153 - loss: 1.0280 - val_accuracy: 0.5512 - val_loss: 1.2048
# Epoch 7/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.6588 - loss: 0.9376 - val_accuracy: 0.5416 - val_loss: 1.2341
# Epoch 8/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.6701 - loss: 0.8844 - val_accuracy: 0.5761 - val_loss: 1.1747
# Epoch 9/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 280s 390ms/step - accuracy: 0.7060 - loss: 0.7922 - val_accuracy: 0.5986 - val_loss: 1.1655
# Epoch 10/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 393ms/step - accuracy: 0.7425 - loss: 0.6952 - val_accuracy: 0.5974 - val_loss: 1.1684
# Epoch 11/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.7718 - loss: 0.6274 - val_accuracy: 0.5972 - val_loss: 1.2324
# Epoch 12/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.8022 - loss: 0.5456 - val_accuracy: 0.6029 - val_loss: 1.2112
# Epoch 13/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.8210 - loss: 0.4885 - val_accuracy: 0.6038 - val_loss: 1.3486
# Epoch 14/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 285s 397ms/step - accuracy: 0.8353 - loss: 0.4469 - val_accuracy: 0.6036 - val_loss: 1.3512
# Epoch 15/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 279s 389ms/step - accuracy: 0.8569 - loss: 0.4023 - val_accuracy: 0.5794 - val_loss: 1.4353
# Epoch 16/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 279s 389ms/step - accuracy: 0.8726 - loss: 0.3611 - val_accuracy: 0.5977 - val_loss: 1.3532
# Epoch 17/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.8761 - loss: 0.3493 - val_accuracy: 0.5881 - val_loss: 1.4657
# Epoch 18/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.8828 - loss: 0.3255 - val_accuracy: 0.5994 - val_loss: 1.5130
# Epoch 19/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.8883 - loss: 0.3020 - val_accuracy: 0.5805 - val_loss: 1.6467
# Epoch 20/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 392ms/step - accuracy: 0.9075 - loss: 0.2667 - val_accuracy: 0.5825 - val_loss: 1.6025
# Epoch 21/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 280s 390ms/step - accuracy: 0.9028 - loss: 0.2682 - val_accuracy: 0.6073 - val_loss: 1.5636
# Epoch 22/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.9163 - loss: 0.2364 - val_accuracy: 0.6033 - val_loss: 1.6131
# Epoch 23/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 283s 393ms/step - accuracy: 0.9186 - loss: 0.2375 - val_accuracy: 0.6139 - val_loss: 1.6628
# Epoch 24/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.9189 - loss: 0.2275 - val_accuracy: 0.5961 - val_loss: 1.7271
# Epoch 25/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9248 - loss: 0.2190 - val_accuracy: 0.6146 - val_loss: 1.7744
# Epoch 26/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 392ms/step - accuracy: 0.9243 - loss: 0.2142 - val_accuracy: 0.6055 - val_loss: 1.7954
# Epoch 27/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 283s 394ms/step - accuracy: 0.9324 - loss: 0.1935 - val_accuracy: 0.6069 - val_loss: 1.7261
# Epoch 28/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 393ms/step - accuracy: 0.9407 - loss: 0.1725 - val_accuracy: 0.6094 - val_loss: 1.7574
# Epoch 29/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9373 - loss: 0.1788 - val_accuracy: 0.5913 - val_loss: 1.6247
# Epoch 30/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.9429 - loss: 0.1652 - val_accuracy: 0.5970 - val_loss: 1.8176
# Epoch 31/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 392ms/step - accuracy: 0.9358 - loss: 0.1828 - val_accuracy: 0.6142 - val_loss: 1.7223
# Epoch 32/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.9395 - loss: 0.1701 - val_accuracy: 0.6125 - val_loss: 1.7099
# Epoch 33/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.9527 - loss: 0.1404 - val_accuracy: 0.5819 - val_loss: 1.8943
# Epoch 34/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 395ms/step - accuracy: 0.9466 - loss: 0.1451 - val_accuracy: 0.6137 - val_loss: 1.8561
# Epoch 35/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 281s 391ms/step - accuracy: 0.9470 - loss: 0.1552 - val_accuracy: 0.6127 - val_loss: 1.8478
# Epoch 36/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9478 - loss: 0.1495 - val_accuracy: 0.6033 - val_loss: 1.7108
# Epoch 37/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 396ms/step - accuracy: 0.9484 - loss: 0.1446 - val_accuracy: 0.5761 - val_loss: 1.7132
# Epoch 38/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9551 - loss: 0.1281 - val_accuracy: 0.6022 - val_loss: 1.9747
# Epoch 39/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9501 - loss: 0.1385 - val_accuracy: 0.5859 - val_loss: 1.8228
# Epoch 40/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 396ms/step - accuracy: 0.9556 - loss: 0.1268 - val_accuracy: 0.6156 - val_loss: 1.9179
# Epoch 41/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 393ms/step - accuracy: 0.9512 - loss: 0.1319 - val_accuracy: 0.6073 - val_loss: 1.9334
# Epoch 42/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9589 - loss: 0.1187 - val_accuracy: 0.5859 - val_loss: 2.0829
# Epoch 43/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 384s 535ms/step - accuracy: 0.9571 - loss: 0.1196 - val_accuracy: 0.6130 - val_loss: 1.8769
# Epoch 44/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 422s 588ms/step - accuracy: 0.9574 - loss: 0.1265 - val_accuracy: 0.5615 - val_loss: 2.0173
# Epoch 45/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 376s 523ms/step - accuracy: 0.9553 - loss: 0.1296 - val_accuracy: 0.6000 - val_loss: 2.0020
# Epoch 46/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 285s 396ms/step - accuracy: 0.9634 - loss: 0.1053 - val_accuracy: 0.6041 - val_loss: 1.8245
# Epoch 47/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 393ms/step - accuracy: 0.9589 - loss: 0.1205 - val_accuracy: 0.6034 - val_loss: 1.8749
# Epoch 48/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 393ms/step - accuracy: 0.9617 - loss: 0.1108 - val_accuracy: 0.6155 - val_loss: 1.9994
# Epoch 49/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 284s 396ms/step - accuracy: 0.9639 - loss: 0.1055 - val_accuracy: 0.5853 - val_loss: 1.9127
# Epoch 50/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 282s 392ms/step - accuracy: 0.9634 - loss: 0.1085 - val_accuracy: 0.6010 - val_loss: 1.8177

# %%
# Save the trained model without optimizer state
model.save('emotion_detection_model.keras', include_optimizer=False)

# Load the trained model
from tensorflow.keras.models import load_model
model = load_model('emotion_detection_model.keras')

# Compile the model (to ensure metrics are available)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import cv2

# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (48, 48))
        roi_gray = roi_gray.astype('float') / 255.0
        roi_gray = np.expand_dims(roi_gray, axis=0)
        roi_gray = np.expand_dims(roi_gray, axis=-1)
        prediction = model.predict(roi_gray)
        maxindex = int(np.argmax(prediction))
        cv2.putText(frame, emotion_labels[maxindex], (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
    cv2.imshow('Emotion Detector', frame)
    
    # Exit the loop when 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
